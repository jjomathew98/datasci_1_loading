# %% [markdown]
# <a href="https://colab.research.google.com/github/jjomathew98/datasci_1_loading/blob/main/HHA507class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# #CSV Datasets

# %%
path = '/content/drive/MyDrive/Electric_Vehicle_Population_Data csvfile1.csv'
data=pd.read_csv(path)
data.head(10)
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year       Make  \
# 0  5UXTA6C03P      King    Seattle    WA      98177.0        2023        BMW
# 1  1FMCU0EZXN    Yakima      Moxee    WA      98936.0        2022       FORD
# 2  1G1FW6S03J      King    Seattle    WA      98117.0        2018  CHEVROLET
# 3  5YJSA1AC0D      King  Newcastle    WA      98059.0        2013      TESLA
# 4  1FADP5CU8F    Kitsap  Bremerton    WA      98312.0        2015       FORD
# 5  WB523CF03P    Yakima      Selah    WA      98942.0        2023        BMW
# 6  YV4BR0CK2K      King   Bellevue    WA      98004.0        2019      VOLVO
# 7  5YJ3E1EA5K  Thurston    Olympia    WA      98506.0        2019      TESLA
# 8  5YJ3E1EB6K    Yakima     Yakima    WA      98902.0        2019      TESLA
# 9  1N4AZ0CP9G      King    Redmond    WA      98052.0        2016     NISSAN
#
#      Model                   Electric Vehicle Type  \
# 0       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %% [markdown]
# ##This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).

# %%
path = '/content/drive/MyDrive/U.S._Chronic_Disease_Indicators__CDI_csv3.csv'
data=pd.read_csv(path)
data.head(10)
# Out:
# <ipython-input-11-c8fb79401c57>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(path)
#    YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0       2010     2010           OR          Oregon       NVSS
# 1       2019     2019           AZ         Arizona      YRBSS
# 2       2019     2019           OH            Ohio      YRBSS
# 3       2019     2019           US   United States      YRBSS
# 4       2015     2015           VI  Virgin Islands      YRBSS
# 5       2020     2020           AL         Alabama      PRAMS
# 6       2015     2015           DE        Delaware      PRAMS
# 7       2019     2019           FL         Florida      PRAMS
# 8       2018     2018           KS          Kansas      PRAMS
# 9       2013     2013           MS     Mississippi      PRAMS
#
#                     Topic                      Question  Response  \
# ...

# %% [markdown]
# ## This dataset CDC's Division of Population Health provides cross-cutting set of 124 indicators that were developed by consensus and that allows states and territories and large metropolitan areas to uniformly define, collect, and report chronic disease data that are important to public health practice and available for states, territories and large metropolitan areas. In addition to providing access to state-specific indicator data, the CDI web site serves as a gateway to additional information and data resources.

# %%
path = '/content/drive/MyDrive/Crime_Data_from_2020_to_Presentcsv2.csv'
data=pd.read_csv(path)
data.head(10)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
# 5  200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30     1
# 6  200100502  01/02/2020 12:00:00 AM  01/02/2020 12:00:00 AM      1315     1
# 7  200100504  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM        40     1
# 8  200100507  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM       200     1
# 9  201710201  06/19/2020 12:00:00 AM  05/26/2020 12:00:00 AM      1925    17
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# ...

# %% [markdown]
# ##This dataset reflects incidents of crime in the City of Los Angeles dating back to 2020. This data is transcribed from original crime reports that are typed on paper and therefore there may be some inaccuracies within the data. Some location fields with missing data are noted as (0°, 0°). Address fields are only provided to the nearest hundred block in order to maintain privacy. This data is as accurate as the data in the database. Please note questions or concerns in the comments.

# %% [markdown]
# #JSON datasets

# %%
import pandas as pd

# %%
data = pd.read_json('https://data.cms.gov/data-api/v1/dataset/f1a8c197-b53d-4c24-9770-aea5d5a97dfb/data')
data.head(10)
# Out:
#                      NPI                        PROVIDER NAME  \
# 0  1003081399 1013055110  BAART BEHAVIORAL HEALTH SERVICES IN
# 1             1003150004                 AMS OF WISCONSIN LLC
# 2             1003362484                         BHG XLII LLC
# 3             1003368945                         RTS EDGEWOOD
# 4             1003571647        METRO TREATMENT OF FLORIDA LP
# 5  1003581174 1326713314            PREMIER CARE OF OHIO, LLC
# 6             1003583733  AFFINITY HEALTHCARE GROUP CHERRY HI
# 7             1003947193  WEST TEXAS COUNSELING & REHABILITAT
# 8             1003953548             ALLIANCE RECOVERY CENTER
# 9             1003953548             ALLIANCE RECOVERY CENTER
#
#               ADDRESS LINE 1                  ADDRESS LINE 2            CITY  \
# 0            617 COMSTOCK RD                           STE 5          BERLIN
# 1      9532 E 16 FRONTAGE RD                         STE 100        ONALASKA
# ...

# %% [markdown]
# ##this dataset shows the Opioid Treatment Program (OTP) Providers dataset provides information on Providers who have enrolled in Medicare under the Opioid Treatment Program. It contains provider's name, National Provider Identifier (NPI), address, phone number and the effective enrollment date.

# %%
data = pd.read_json('https://data.cms.gov/data-api/v1/dataset/137f90cb-ac53-4b3d-8358-e65cf64e03d3/data')
data.head(10)
# Out:
#   week_ending  federal_provider_number             provider_name  \
# 0  2020-05-24                    15009  BURNS NURSING HOME, INC.
# 1  2020-05-31                    15009  BURNS NURSING HOME, INC.
# 2  2020-06-07                    15009  BURNS NURSING HOME, INC.
# 3  2020-06-14                    15009  BURNS NURSING HOME, INC.
# 4  2020-06-21                    15009  BURNS NURSING HOME, INC.
# 5  2020-06-28                    15009  BURNS NURSING HOME, INC.
# 6  2020-07-05                    15009  BURNS NURSING HOME, INC.
# 7  2020-07-12                    15009  BURNS NURSING HOME, INC.
# 8  2020-07-19                    15009  BURNS NURSING HOME, INC.
# 9  2020-07-26                    15009  BURNS NURSING HOME, INC.
#
#        provider_address provider_city provider_state  provider_zip_code  \
# 0  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 1  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# ...

# %% [markdown]
# ## This dataset shows Information on COVID-19 reported by nursing homes to the CDC’s National Healthcare Safety Network (NHSN) COVID-19 Long Term Care Facility Module.

# %%
data = pd.read_json('https://data.cms.gov/data-api/v1/dataset/5f9f1216-6fd9-455d-bfbc-0efade687a4e/data')
data.head(10)
# Out:
#    Year STATE_NAME COUNTY_NAME  STATE_ID  COUNTY_ID Per_Capita_Exp_ESRD  \
# 0  2022    Alabama     Autauga         1          0            79216.61
# 1  2022    Alabama     Baldwin         1         10            80017.74
# 2  2022    Alabama     Barbour         1         20            76970.88
# 3  2022    Alabama        Bibb         1         30            79077.19
# 4  2022    Alabama      Blount         1         40            67133.38
# 5  2022    Alabama     Bullock         1         50            93880.76
# 6  2022    Alabama      Butler         1         60            75160.43
# 7  2022    Alabama     Calhoun         1         70            81941.48
# 8  2022    Alabama    Chambers         1         80            68672.24
# 9  2022    Alabama    Cherokee         1         90            73256.44
#
#   Avg_Risk_Score_ESRD Person_Years_ESRD Per_Capita_Exp_DIS Avg_Risk_Score_DIS  \
# 0             0.98136             30.67            8647.25            0.89556
# ...

# %% [markdown]
# ##this dataset talks about the County-level Aggregate Expenditure and Risk Score Data on Assignable Beneficiaries PUF for the Medicare Shared Savings Program (Shared Savings Program) provides aggregate data consisting of per capita Parts A and B FFS expenditures, average CMS-HCC prospective risk scores and total person-years for assignable beneficiaries by Medicare enrollment type

# %% [markdown]
# #XLSX Datasets

# %%
import pandas as pd

# %%
path ="/content/drive/MyDrive/list-of-insp-rpts-lastyear-datasetxlsx3.xlsx"
data=pd.read_excel(path)
data.head(10)
# Out:
#                      DOC_TITLE     DOC_DT             SITE_NAME  \
# 0  Inspection Report - 2023001  3/31/2023  Arkansas Nuclear One
# 1  Inspection Report - 2023010  2/17/2023         Beaver Valley
# 2  Inspection Report - 2023001  3/31/2023         Beaver Valley
# 3  Inspection Report - 2023001  3/31/2023             Braidwood
# 4  Inspection Report - 2023440  2/17/2023          Browns Ferry
# 5  Inspection Report - 2023401   2/9/2023          Browns Ferry
# 6  Inspection Report - 2023091  3/25/2023          Browns Ferry
# 7  Inspection Report - 2023090  2/13/2023          Browns Ferry
# 8  Inspection Report - 2023001  3/31/2023          Browns Ferry
# 9  Inspection Report - 2023001  3/31/2023             Brunswick
#
#                                              RPT_URL ACCESSION_NO
# 0  =hyperlink("http://adamswebsearch2.nrc.gov/idm...  ML23129A788
# 1  =hyperlink("http://adamswebsearch2.nrc.gov/idm...  ML23067A022
# ...

# %% [markdown]
# ## this dataset mainly tells us the Official Correspondence of Nuclear Reactor Inspection Reports in site locations and the reports are included within the excel sheets as well.

# %%
data = pd.read_excel('/content/drive/MyDrive/DeathProbsE_F_Alt2_TR2014xlsc.xlsx')
data.head(10)
# Out:
#   Probability of death for females by calendar year and by single year of age (ages 0 to 119).  \
# 0                                               Year
# 1                                               2011
# 2                                               2012
# 3                                               2013
# 4                                               2014
# 5                                               2015
# 6                                               2016
# 7                                               2017
# 8                                               2018
# 9                                               2019
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0    0.000000    1.000000    2.000000    3.000000    4.000000    5.000000
# 1    0.005821    0.000374    0.000244    0.000182    0.000136    0.000122
# 2    0.005770    0.000367    0.000239    0.000179    0.000134    0.000120
# ...

# %% [markdown]
# ## This dataset mainly provide historical and projected probabilities of death by age, gender, and year for the period 2011 - 2090. Death probabilities for females.

# %%
data = pd.read_excel('/content/drive/MyDrive/EEO1 2017 PUF.xlsx')
data.head(10)
# Out:
#           Nation Region Division State CBSA County  NAICS2  \
# 0  United States    NaN      NaN   NaN  NaN    NaN     NaN
# 1  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 2  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 3  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 4  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 5  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 6  United States    NaN      NaN   NaN  NaN    NaN    11.0
# 7  United States    NaN      NaN   NaN  NaN    NaN    21.0
# 8  United States    NaN      NaN   NaN  NaN    NaN    21.0
# 9  United States    NaN      NaN   NaN  NaN    NaN    21.0
#
#                                      NAICS2_Name  NAICS3  \
# 0                                            NaN     NaN
# 1     Agriculture, Forestry, Fishing and Hunting     NaN
# 2     Agriculture, Forestry, Fishing and Hunting   111.0
# 3     Agriculture, Forestry, Fishing and Hunting   112.0
# ...
